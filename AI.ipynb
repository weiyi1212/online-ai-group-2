# %%
import pandas as pd
import sklearn
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv("log_mini.csv")

# %%
#show data
df.describe()
# Out:
#        session_position  session_length  context_switch  no_pause_before_play  \
# count     167880.000000   167880.000000   167880.000000         167880.000000
# mean           9.325911       17.651823        0.040904              0.767602
# std            5.457638        3.422025        0.198069              0.422363
# min            1.000000       10.000000        0.000000              0.000000
# 25%            5.000000       15.000000        0.000000              1.000000
# 50%            9.000000       20.000000        0.000000              1.000000
# 75%           14.000000       20.000000        0.000000              1.000000
# max           20.000000       20.000000        1.000000              1.000000
#
#        short_pause_before_play  long_pause_before_play  \
# count            167880.000000           167880.000000
# mean                  0.146635                0.172832
# std                   0.353742                0.378103
# min                   0.000000                0.000000
# 25%                   0.000000                0.000000
# 50%                   0.000000                0.000000
# 75%                   0.000000                0.000000
# max                   1.000000                1.000000
#
#        hist_user_behavior_n_seekfwd  hist_user_behavior_n_seekback  \
# count                 167880.000000                  167880.000000
# mean                       0.038909                       0.046259
# std                        0.367295                       0.606558
# min                        0.000000                       0.000000
# 25%                        0.000000                       0.000000
# 50%                        0.000000                       0.000000
# 75%                        0.000000                       0.000000
# max                       60.000000                     151.000000
#
#          hour_of_day
# count  167880.000000
# mean       14.193084
# std         5.996243
# min         0.000000
# 25%        11.000000
# 50%        15.000000
# 75%        19.000000
# max        23.000000

# %%
df = df.drop(["session_position"], axis=1)
#df = df.drop(["session_id"],axis = 1)
#y = train.pop("track_id_clean")
#y = train.pop("date")
#y = train.pop("context_type")
#y = train.pop("hist_user_behavior_reason_start")
#y = train.pop("hist_user_behavior_reason_end")
"session_position" in df.columns
# Out:
# False

# %%
print(df.columns)
# Out:
# Index(['session_id', 'session_length', 'track_id_clean', 'skip_1', 'skip_2',
#        'skip_3', 'not_skipped', 'context_switch', 'no_pause_before_play',
#        'short_pause_before_play', 'long_pause_before_play',
#        'hist_user_behavior_n_seekfwd', 'hist_user_behavior_n_seekback',
#        'hist_user_behavior_is_shuffle', 'hour_of_day', 'date', 'premium',
#        'context_type', 'hist_user_behavior_reason_start',
#        'hist_user_behavior_reason_end'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split

# %%
train, test = train_test_split(df, test_size = 0.2)

# %%
train
# Out:
#                                     session_id  session_length  \
# 77978   0_06bf3805-2bc9-4dff-99de-a3ca0604cfcd              20
# 16063   0_0157a3e6-0368-434d-a38c-9db61940a535              18
# 19421   0_01add820-11c7-4164-94b5-34a291aee215              20
# 105569  0_0931bad7-9736-4192-a9e8-fd41a019079e              20
# 48186   0_04265be7-3b6c-4bfe-8895-5fad83557b2c              20
# ...                                        ...             ...
# 145014  0_0cb4c57c-80fd-4f2e-8fe4-695cf12b5d8f              19
# 159076  0_0dea7e4d-9c72-48f5-a4d3-ca97193f7a42              20
# 18829   0_019f14cc-060f-4c52-bf14-514f7252a524              20
# 553     0_0009bdeb-b5b7-4073-9b01-b72a32c77cda              20
# 149048  0_0d0b8547-fbf5-4403-a662-1dc065637886              16
#
#                                 track_id_clean  skip_1  skip_2  skip_3  \
# 77978   t_3543c90a-63f0-48f6-829e-640a006f9f92   False   False    True
# 16063   t_58fbb965-6308-42b3-abba-6995ece14eca   False   False   False
# 19421   t_4093c619-a2ea-49bd-8023-f14ee770b40b    True    True    True
# 105569  t_1e1d0f01-a6f4-479c-9e2b-161d6005e86a   False   False    True
# 48186   t_eb5fef24-ca7f-4a75-a471-c021fc044280    True    True    True
# ...                                        ...     ...     ...     ...
# 145014  t_647637a0-534f-4962-814b-4f9108bd0570    True    True    True
# 159076  t_0ef7633c-c54c-42d0-9a87-3abce00b51d6   False   False   False
# 18829   t_a44715f2-1a3d-449a-8672-7721f4e9c4b4   False   False   False
# 553     t_9a31436c-a57a-4d7a-9bbc-50f0deca33de    True    True    True
# 149048  t_a735a4c8-63b5-4d10-85fb-467da63f2230   False   False    True
#
#         not_skipped  context_switch  no_pause_before_play  \
# 77978         False               0                     1
# 16063          True               0                     0
# 19421         False               0                     1
# 105569        False               1                     1
# 48186         False               0                     1
# ...             ...             ...                   ...
# 145014        False               0                     1
# 159076         True               0                     1
# 18829          True               0                     1
# 553           False               0                     0
# 149048        False               1                     1
#
#         short_pause_before_play  long_pause_before_play  \
# 77978                         0                       0
# 16063                         0                       0
# 19421                         0                       0
# 105569                        0                       0
# 48186                         0                       0
# ...                         ...                     ...
# 145014                        0                       0
# 159076                        0                       0
# 18829                         0                       0
# 553                           1                       1
# 149048                        0                       0
#
#         hist_user_behavior_n_seekfwd  hist_user_behavior_n_seekback  \
# 77978                              0                              0
# 16063                              0                              0
# 19421                              0                              0
# 105569                             0                              0
# 48186                              0                              1
# ...                              ...                            ...
# 145014                             0                              0
# 159076                             0                              0
# 18829                              0                              0
# 553                                0                              0
# 149048                             0                              0
#
#         hist_user_behavior_is_shuffle  hour_of_day        date  premium  \
# 77978                            True           20  2018-07-14     True
# 16063                           False           14  2018-07-15     True
# 19421                           False           11  2018-07-15     True
# 105569                          False           14  2018-07-15     True
# 48186                           False            8  2018-07-15     True
# ...                               ...          ...         ...      ...
# 145014                          False           21  2018-07-14     True
# 159076                          False           16  2018-07-15     True
# 18829                           False           19  2018-07-14    False
# 553                              True           21  2018-07-14    False
# 149048                          False           19  2018-07-15     True
#
#               context_type hist_user_behavior_reason_start  \
# 77978              catalog                       trackdone
# 16063      user_collection                       trackdone
# 19421   editorial_playlist                         backbtn
# 105569             catalog                          fwdbtn
# 48186      user_collection                          fwdbtn
# ...                    ...                             ...
# 145014               radio                          fwdbtn
# 159076               radio                       trackdone
# 18829   editorial_playlist                       trackdone
# 553        user_collection                          fwdbtn
# 149048             catalog                        clickrow
#
#        hist_user_behavior_reason_end
# 77978                        endplay
# 16063                      trackdone
# 19421                        backbtn
# 105569                        remote
# 48186                        backbtn
# ...                              ...
# 145014                        fwdbtn
# 159076                     trackdone
# 18829                      trackdone
# 553                           fwdbtn
# 149048                       endplay
#
# [134304 rows x 20 columns]

# %%
#np.dtype(['session_id'])

# %%
train = train.drop(["session_id"], axis = 1)
train = train.drop(["track_id_clean"], axis=1)
train = train.drop(["date"],axis = 1)
train = train.drop(["context_type"],axis=1)
train = train.drop(["hist_user_behavior_reason_start"],axis=1)
train = train.drop(["hist_user_behavior_reason_end"],axis=1)

# %%
train
# Out:
#         session_length  skip_1  skip_2  skip_3  not_skipped  context_switch  \
# 77978               20   False   False    True        False               0
# 16063               18   False   False   False         True               0
# 19421               20    True    True    True        False               0
# 105569              20   False   False    True        False               1
# 48186               20    True    True    True        False               0
# ...                ...     ...     ...     ...          ...             ...
# 145014              19    True    True    True        False               0
# 159076              20   False   False   False         True               0
# 18829               20   False   False   False         True               0
# 553                 20    True    True    True        False               0
# 149048              16   False   False    True        False               1
#
#         no_pause_before_play  short_pause_before_play  long_pause_before_play  \
# 77978                      1                        0                       0
# 16063                      0                        0                       0
# 19421                      1                        0                       0
# 105569                     1                        0                       0
# 48186                      1                        0                       0
# ...                      ...                      ...                     ...
# 145014                     1                        0                       0
# 159076                     1                        0                       0
# 18829                      1                        0                       0
# 553                        0                        1                       1
# 149048                     1                        0                       0
#
#         hist_user_behavior_n_seekfwd  hist_user_behavior_n_seekback  \
# 77978                              0                              0
# 16063                              0                              0
# 19421                              0                              0
# 105569                             0                              0
# 48186                              0                              1
# ...                              ...                            ...
# 145014                             0                              0
# 159076                             0                              0
# 18829                              0                              0
# 553                                0                              0
# 149048                             0                              0
#
#         hist_user_behavior_is_shuffle  hour_of_day  premium
# 77978                            True           20     True
# 16063                           False           14     True
# 19421                           False           11     True
# 105569                          False           14     True
# 48186                           False            8     True
# ...                               ...          ...      ...
# 145014                          False           21     True
# 159076                          False           16     True
# 18829                           False           19    False
# 553                              True           21    False
# 149048                          False           19     True
#
# [134304 rows x 14 columns]

# %%
test = test.drop(("track_id_clean"), axis=1)
test = test.drop(("session_id"), axis=1)
test = test.drop(("date"), axis=1)
test = test.drop(("context_type"), axis=1)
test = test.drop(("hist_user_behavior_reason_start"), axis=1)
test = test.drop(("hist_user_behavior_reason_end"), axis=1)

# %%
#df_test.session_length.hist(bins=50)

# %%
#train, test = train_test_split(df.values, test_size = 0.2)

# %%
y = train.pop("not_skipped")

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression().fit(train,y)

# %%
y_test = test.pop("not_skipped")

# %%
predicted = model.predict(test)

# %%
df_test = pd.DataFrame(y_test)

# %%
df_test
# Out:
#         not_skipped
# 111856        False
# 118861        False
# 66742         False
# 126902        False
# 92016         False
# ...             ...
# 141687        False
# 136118        False
# 75669         False
# 147511        False
# 108336         True
#
# [33576 rows x 1 columns]

# %%
df_test["predicted"] = predicted
#df_test["session_length"] = session_length

# %%
sns.lineplot("not_skipped","predicted", data = df_test)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-521-dd1f1cf1aaa8> in <module>
# ----> 1 sns.lineplot("not_skipped","predicted", data = df_test)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/seaborn/relational.py in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, sort, err_style, err_kws, legend, ax, **kwargs)
#    1082         ax = plt.gca()
#    1083
# -> 1084     p.plot(ax, kwargs)
#    1085
#    1086     return ax
#
# ~/opt/anaconda3/lib/python3.7/site-packages/seaborn/relational.py in plot(self, ax, kws)
#     808                 if self.err_style == "band":
#     809
# --> 810                     ax.fill_between(x, low, high, color=line_color, **err_kws)
#     811
#     812                 elif self.err_style == "bars":
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1599     def inner(ax, *args, data=None, **kwargs):
#    1600         if data is None:
# -> 1601             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1602
#    1603         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in fill_between(self, x, y1, y2, where, interpolate, step, **kwargs)
#    5222
#    5223         # Convert the arrays so we can work with them
# -> 5224         x = ma.masked_invalid(self.convert_xunits(x))
#    5225         y1 = ma.masked_invalid(self.convert_yunits(y1))
#    5226         y2 = ma.masked_invalid(self.convert_yunits(y2))
#
# ~/opt/anaconda3/lib/python3.7/site-packages/numpy/ma/core.py in masked_invalid(a, copy)
#    2364         cls = type(a)
#    2365     else:
# -> 2366         condition = ~(np.isfinite(a))
#    2367         cls = MaskedArray
#    2368     result = a.view(cls)
#
# TypeError: ufunc 'isfinite' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
df_test.plot(x="not_skipped", y ="predicted", kind = "line")

# %%
df_test.head()

# %%
# montella for binary classifcation
