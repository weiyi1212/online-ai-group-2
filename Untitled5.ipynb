# %%
import pandas as pd
import sklearn 
import seaborn as sns 
import numpy as np
import random
random.seed(5483)

# %%
tf = pd.read_csv("tf_mini.csv")

# %%
tf.describe()
# Out:
#            duration  release_year  us_popularity_estimate  acousticness  \
# count  50704.000000  50704.000000            50704.000000  50704.000000
# mean     222.267980   2010.324748               99.455131      0.250336
# std       72.224839     11.471866                1.139222      0.276047
# min       30.013330   1950.000000               90.018900      0.000000
# 25%      183.933334   2009.000000               99.509670      0.025291
# 50%      214.866669   2015.000000               99.865444      0.135821
# 75%      250.426666   2017.000000               99.961131      0.406142
# max     1787.760986   2018.000000               99.999997      0.995796
#
#        beat_strength    bounciness  danceability  dyn_range_mean  \
# count   50704.000000  50704.000000  50704.000000    50704.000000
# mean        0.492075      0.514526      0.611742        8.215950
# std         0.158102      0.182595      0.166146        2.410626
# ...

# %%
from sklearn.model_selection import train_test_split

train, test = train_test_split(tf, test_size=0.2)

# %%
train
# Out:
#                                      track_id    duration  release_year  \
# 44657  t_dbf083e0-b1f5-4047-97ac-0adbd80d1e50  136.333054          2015
# 5092   t_dcc91e8f-4ae8-4976-957f-fec43ff3ac28  185.668839          2018
# 2465   t_62a1b05f-e1c2-4c62-9157-a7a49337a79e  212.960007          2014
# 25794  t_216eca28-485e-4259-a672-7a60578f0d3b  302.693329          1984
# 8319   t_5b51ea35-bd40-4e6a-9341-11bf213e379a  199.986664          2016
# ...                                       ...         ...           ...
# 1783   t_6136a673-2679-44a0-a5c4-0d35214aff8b  263.933319          2011
# 45219  t_d7fab709-8b77-4156-b004-23c5262ca737  270.266663          2016
# 46742  t_8cfa4616-4192-4b5d-897c-ddd2cb9479ef  260.186676          1979
# 45517  t_6388c9ff-09d2-412e-8595-7dfda030ea12  221.609802          2017
# 10735  t_e7d1497d-3b5b-49f2-95bf-08660ee892e2  211.143951          2018
#
#        us_popularity_estimate  acousticness  beat_strength  bounciness  \
# ...

# %%
test
# Out:
#                                      track_id    duration  release_year  \
# 30451  t_1f8d9266-b88f-40a3-b447-44f1df28b6c0  200.626663          2005
# 35478  t_2fc84191-f305-47b8-ab66-0374316ebca0  200.053329          2011
# 34218  t_5148594d-dab6-462a-af72-f6e40cd407cd  167.741898          2018
# 26154  t_aa71fcf0-158f-4bac-a1e2-db00cca0fda4  158.906677          2003
# 30062  t_fce1aad4-2a97-4e81-8151-e890b7dfc478  240.293335          2000
# ...                                       ...         ...           ...
# 7548   t_8d593eb9-423b-4711-9fc7-1b1e8df677e2  180.813324          2014
# 5264   t_31e1503f-ceca-4ebc-9ccd-2320dcb971c1  147.360001          2018
# 38788  t_e165d1a9-126c-4ed5-ae67-e0b466626f1b  276.600006          1992
# 48312  t_3145ebbd-5a4c-41f8-8237-6652ffe5b017  429.666656          2014
# 11141  t_61d255b9-d2d7-459f-a328-9739bb0b4f1e  186.597015          2018
#
#        us_popularity_estimate  acousticness  beat_strength  bounciness  \
# ...

# %%
train = train.drop(("track_id"), axis=1)
train = train.drop(("release_year"), axis=1)
train = train.drop(("time_signature"), axis=1)
train = train.drop(("acoustic_vector_0"), axis=1)
train = train.drop(("acoustic_vector_1"), axis=1)
train = train.drop(("acoustic_vector_2"), axis=1)
train = train.drop(("mode"), axis=1)

# %%
train
# Out:
#          duration  us_popularity_estimate  acousticness  beat_strength  \
# 44657  136.333054               94.206364      0.690481       0.581623
# 5092   185.668839               99.963554      0.888985       0.622662
# 2465   212.960007               99.991447      0.028948       0.390180
# 25794  302.693329               99.973042      0.321351       0.757639
# 8319   199.986664               99.861000      0.000766       0.391863
# ...           ...                     ...           ...            ...
# 1783   263.933319               99.881547      0.151760       0.363342
# 45219  270.266663               99.832998      0.347111       0.248834
# 46742  260.186676               99.871821      0.167191       0.616831
# 45517  221.609802               99.380576      0.810174       0.658860
# 10735  211.143951               99.940572      0.011554       0.452696
#
#        bounciness  danceability  dyn_range_mean    energy  flatness  \
# ...

# %%
test = test.drop(("track_id"), axis=1)
test = test.drop(("release_year"), axis=1)
test = test.drop(("time_signature"), axis=1)
test = test.drop(("acoustic_vector_0"), axis=1)
test = test.drop(("acoustic_vector_1"), axis=1)
test = test.drop(("acoustic_vector_2"), axis=1)
test = test.drop(("mode"), axis=1)

# %%
test
# Out:
#          duration  us_popularity_estimate  acousticness  beat_strength  \
# 30451  200.626663               99.861982      0.064264       0.483984
# 35478  200.053329               99.913732      0.021987       0.274801
# 34218  167.741898               99.918603      0.025155       0.593016
# 26154  158.906677               99.860897      0.035244       0.499687
# 30062  240.293335               99.829550      0.019399       0.666885
# ...           ...                     ...           ...            ...
# 7548   180.813324               99.715395      0.599925       0.482093
# 5264   147.360001               99.152391      0.000296       0.609442
# 38788  276.600006               99.481760      0.425774       0.443187
# 48312  429.666656               99.897342      0.049480       0.583267
# 11141  186.597015               99.972640      0.487469       0.548102
#
#        bounciness  danceability  dyn_range_mean    energy  flatness  \
# ...

# %%
y = train.pop("danceability")

# %%
from sklearn.linear_model import LinearRegression


model = LinearRegression().fit(train, y)

# %%
y_test = test.pop("danceability")

# %%
predicted = model.predict(test)

# %%
tf_test = pd.DataFrame(y_test)

# %%
tf_test
# Out:
#        danceability
# 30451      0.612599
# 35478      0.398986
# 34218      0.750840
# 26154      0.657722
# 30062      0.805148
# ...             ...
# 7548       0.549238
# 5264       0.783650
# 38788      0.575403
# 48312      0.530892
# 11141      0.643522
#
# [10141 rows x 1 columns]

# %%
tf_test["predicted"] = predicted

# %%
sns.lineplot("danceability","predicted", data = tf_test)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='danceability', ylabel='predicted'>

# %%
tf_test
# Out:
#        danceability  predicted
# 30451      0.612599   0.637456
# 35478      0.398986   0.450044
# 34218      0.750840   0.698442
# 26154      0.657722   0.618696
# 30062      0.805148   0.832625
# ...             ...        ...
# 7548       0.549238   0.576831
# 5264       0.783650   0.766545
# 38788      0.575403   0.585724
# 48312      0.530892   0.606216
# 11141      0.643522   0.706926
#
# [10141 rows x 2 columns]

# %%
tf_test.plot(x="danceability", y="predicted", kind= "line")
# Out:
# <AxesSubplot:xlabel='danceability'>

# %%
tf_test.head()
# Out:
#        danceability  predicted
# 30451      0.612599   0.637456
# 35478      0.398986   0.450044
# 34218      0.750840   0.698442
# 26154      0.657722   0.618696
# 30062      0.805148   0.832625

# %%
import os
