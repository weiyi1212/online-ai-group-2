# %%
import pandas as pd
import sklearn 
import seaborn as sns 
import numpy as np

# %%
df = pd.read_csv("log_mini.csv")

# %%
df.describe()
# Out:
#        session_position  session_length  context_switch  no_pause_before_play  \
# count     167880.000000   167880.000000   167880.000000         167880.000000
# mean           9.325911       17.651823        0.040904              0.767602
# std            5.457638        3.422025        0.198069              0.422363
# min            1.000000       10.000000        0.000000              0.000000
# 25%            5.000000       15.000000        0.000000              1.000000
# 50%            9.000000       20.000000        0.000000              1.000000
# 75%           14.000000       20.000000        0.000000              1.000000
# max           20.000000       20.000000        1.000000              1.000000
#
#        short_pause_before_play  long_pause_before_play  \
# count            167880.000000           167880.000000
# mean                  0.146635                0.172832
# std                   0.353742                0.378103
# ...

# %%
df = df.drop(["hour_of_day"], axis=1)

# %%
from sklearn.model_selection import train_test_split

train, test = train_test_split(df, test_size=0.2)

# %%
train
# Out:
#                                     session_id  session_position  \
# 160848  0_0e10a053-5a03-428c-b40b-6a5d874ca6ba                 6
# 133405  0_0bb04723-e0d1-469a-af32-d7a2a24f0ad8                 8
# 129606  0_0b5e5e81-6a88-4669-8b76-94784ecf4ab2                19
# 78795   0_06d56f83-9b49-4b83-b79a-0ceaba9799ef                16
# 107889  0_09651ef1-e78b-47bc-a09a-601712855984                 1
# ...                                        ...               ...
# 4003    0_00529630-d19f-4c57-8418-298976de74b1                12
# 99633   0_08af4b5c-d18c-4587-8d73-e9915fb7e04f                16
# 16119   0_015820dd-f4c2-442d-8982-b4fb123d526b                 7
# 70561   0_06166f2f-422e-4a4a-9986-684bc8f3246b                 3
# 143170  0_0c8bf8f4-5871-40b3-958b-fa7deacaf5d5                 2
#
#         session_length                          track_id_clean  skip_1  \
# 160848              10  t_f39f8143-f5b3-413b-a11c-04634af5ae71   False
# ...

# %%
test
# Out:
#                                     session_id  session_position  \
# 91729   0_07f7940e-c2dc-4d1f-a0e2-1af0b89a8633                13
# 41959   0_039d7d11-0009-4201-af07-5160ea4959b9                20
# 123592  0_0ad72076-52cb-406b-b878-4377e091bd98                19
# 7131    0_00988638-684e-4257-ba9c-301ebdda50b0                 2
# 58856   0_050509d4-682c-4e17-8d1d-261598590914                 3
# ...                                        ...               ...
# 58147   0_04f1d520-3d82-4df4-a878-add2edd63d41                10
# 159576  0_0df418f7-7ae5-4d2c-aeb0-383c7ec2af26                 3
# 86653   0_0788fb5b-df3d-4b60-9f0c-a2408e251bc0                19
# 77244   0_06b13698-3507-4761-bbb7-e9fb88b6ded6                 4
# 120404  0_0a8e1367-c48f-4719-a7b6-e5a7373000c5                16
#
#         session_length                          track_id_clean  skip_1  \
# 91729               20  t_77b02acb-1b1f-4b36-b8fc-2c3e01892b9a    True
# ...

# %%
train = train.drop(("track_id_clean"), axis=1)
train = train.drop(("session_id"), axis=1)
train = train.drop(("date"), axis=1)
train = train.drop(("context_type"), axis=1)
train = train.drop(("hist_user_behavior_reason_start"), axis=1)
train = train.drop(("hist_user_behavior_reason_end"), axis=1)

# %%
train
# Out:
#         session_position  session_length  skip_1  skip_2  skip_3  not_skipped  \
# 160848                 6              10   False    True    True        False
# 133405                 8              20    True    True    True        False
# 129606                19              20   False    True    True        False
# 78795                 16              20    True    True    True        False
# 107889                 1              20   False   False    True        False
# ...                  ...             ...     ...     ...     ...          ...
# 4003                  12              20   False    True    True        False
# 99633                 16              20    True    True    True        False
# 16119                  7              14   False    True    True        False
# 70561                  3              11   False   False    True        False
# 143170                 2              20    True    True    True        False
#
# ...

# %%
test = test.drop(("track_id_clean"), axis=1)
test = test.drop(("session_id"), axis=1)
test = test.drop(("date"), axis=1)
test = test.drop(("context_type"), axis=1)
test = test.drop(("hist_user_behavior_reason_start"), axis=1)
test = test.drop(("hist_user_behavior_reason_end"), axis=1)

# %%
test
# Out:
#         session_position  session_length  skip_1  skip_2  skip_3  not_skipped  \
# 91729                 13              20    True    True    True        False
# 41959                 20              20   False   False   False         True
# 123592                19              20   False   False   False         True
# 7131                   2              13   False   False   False         True
# 58856                  3              20    True    True    True        False
# ...                  ...             ...     ...     ...     ...          ...
# 58147                 10              15    True    True    True        False
# 159576                 3              10    True    True    True        False
# 86653                 19              20    True    True    True        False
# 77244                  4              20    True    True    True        False
# 120404                16              20    True    True    True        False
#
# ...

# %%
y = train.pop("session_length")

# %%
from sklearn.linear_model import LinearRegression


model = LinearRegression().fit(train, y)

# %%
y_test = test.pop("session_length")

# %%
predicted = model.predict(test)

# %%
predicted
# Out:
# array([18.75369935, 19.62666765, 19.53424518, ..., 19.43108714,
#        16.98369875, 19.50006595])

# %%
df_test = pd.DataFrame(y_test)

# %%
df_test
# Out:
#         session_length
# 91729               20
# 41959               20
# 123592              20
# 7131                13
# 58856               20
# ...                ...
# 58147               15
# 159576              10
# 86653               20
# 77244               20
# 120404              20
#
# [33576 rows x 1 columns]

# %%
df_test["predicted"] = predicted

# %%
sns.lineplot("session_length","predicted", data = df_test)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='session_length', ylabel='predicted'>

# %%
df_test.plot(x="session_length", y="predicted", kind= "line")
# Out:
# <AxesSubplot:xlabel='session_length'>

# %%
df_test.head()
# Out:
#         session_length  predicted
# 91729               20  18.753699
# 41959               20  19.626668
# 123592              20  19.534245
# 7131                13  15.796145
# 58856               20  16.774001
